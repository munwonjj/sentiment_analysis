# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')

import nltk

# %%
# # run this cell if you don't have punkt installed and have SSL issues
# import nltk
# import ssl

# try:
#     _create_unverified_https_context = ssl._create_unverified_context
# except AttributeError:
#     pass
# else:
#     ssl._create_default_https_context = _create_unverified_https_context

# nltk.download()

# %%
# Read the data
df = pd.read_csv('Reviews.csv')

# %%
subset_df = df.iloc[:3000]
subset_df.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# ...

# %%
df.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# ...

# %%
df['Text'].values[0]
# Out:
# 'I have bought several of the Vitality canned dog food products and have found them all to be of good quality. The product looks more like a stew than a processed meat and it smells better. My Labrador is finicky and she appreciates this product better than  most.'

# %% [markdown]
# ## EDA

# %%
df.describe()
# Out:
#                   Id  HelpfulnessNumerator  HelpfulnessDenominator  \
# count  568454.000000         568454.000000            568454.00000
# mean   284227.500000              1.743817                 2.22881
# std    164098.679298              7.636513                 8.28974
# min         1.000000              0.000000                 0.00000
# 25%    142114.250000              0.000000                 0.00000
# 50%    284227.500000              0.000000                 1.00000
# 75%    426340.750000              2.000000                 2.00000
# max    568454.000000            866.000000               923.00000
#
#                Score          Time
# count  568454.000000  5.684540e+05
# mean        4.183199  1.296257e+09
# std         1.310436  4.804331e+07
# min         1.000000  9.393408e+08
# 25%         4.000000  1.271290e+09
# 50%         5.000000  1.311120e+09
# 75%         5.000000  1.332720e+09
# max         5.000000  1.351210e+09

# %%
ax = df['Score'].value_counts().sort_index().plot(kind='bar', title='Count of Reviews by Stars', figsize = (10,5))
ax.set_xlabel('Review Stars')
plt.show()

# %% [markdown]
# ## Basic NLTK

# %%
example = df['Text'][50]
print(example)
# Out:
# This oatmeal is not good. Its mushy, soft, I don't like it. Quaker Oats is the way to go.

# %%
tokens = nltk.word_tokenize(example)
tokens[:10]
# Out:
# ['This', 'oatmeal', 'is', 'not', 'good', '.', 'Its', 'mushy', ',', 'soft']

# %%
# part of speech tagging
tagged = nltk.pos_tag(tokens)
tagged[:10]
# Out:
# [('This', 'DT'),
#  ('oatmeal', 'NN'),
#  ('is', 'VBZ'),
#  ('not', 'RB'),
#  ('good', 'JJ'),
#  ('.', '.'),
#  ('Its', 'PRP$'),
#  ('mushy', 'NN'),
#  (',', ','),
#  ('soft', 'JJ')]

# %%
entities = nltk.chunk.ne_chunk(tagged)
entities.pprint()
# Out:
# (S
#   This/DT
#   oatmeal/NN
#   is/VBZ
#   not/RB
#   good/JJ
#   ./.
#   Its/PRP$
#   mushy/NN
#   ,/,
#   soft/JJ
#   ,/,
#   I/PRP
#   do/VBP
#   n't/RB
#   like/VB
#   it/PRP
#   ./.
#   (ORGANIZATION Quaker/NNP Oats/NNPS)
#   is/VBZ
#   the/DT
#   way/NN
#   to/TO
#   go/VB
#   ./.)

# %% [markdown]
# ## Step 1. VADER Sentiment Scoring
# - VADER (Valence Aware Dictionary and sentiment reasoner) - Bag of words approach
# - NLTK's SentimentIntensityAnalyzer will be used to get the neg/neu/pos scores of the text
#
# This uses "bags of words" approach:
# 1. Stop words are removed
# 2. Each word is scored and combined to a total score

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
from tqdm.notebook import tqdm

sia = SentimentIntensityAnalyzer()

# %%
sia.polarity_scores('I am so happy!')
# Out:
# {'neg': 0.0, 'neu': 0.318, 'pos': 0.682, 'compound': 0.6468}

# %%
sia.polarity_scores('This waffle is very soggy.')
# Out:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
sia.polarity_scores(example)
# Out:
# {'neg': 0.22, 'neu': 0.78, 'pos': 0.0, 'compound': -0.5448}

# %%
# run the polarity score on the entire dataset
res = {}

for i, row in tqdm(subset_df.iterrows(), total=len(subset_df)):
    text = row['Text']
    myid = row['Id']
    res[myid] = sia.polarity_scores(text)
# Out:
#   0%|          | 0/3000 [00:00<?, ?it/s]

# %%
pd.DataFrame(res)
# Out:
#             1       2       3     4       5      6       7       8       9     \
# neg       0.0000  0.1380  0.0910   0.0  0.0000  0.029  0.0340  0.0000  0.0000
# neu       0.6950  0.8620  0.7540   1.0  0.5520  0.809  0.6930  0.5200  0.8510
# pos       0.3050  0.0000  0.1550   0.0  0.4480  0.163  0.2730  0.4800  0.1490
# compound  0.9441 -0.5664  0.8265   0.0  0.9468  0.883  0.9346  0.9487  0.6369
#
#             10    ...    2991    2992    2993    2994    2995    2996    2997  \
# neg       0.0000  ...  0.0250  0.0000  0.0000  0.0000  0.0000  0.1040  0.0000
# neu       0.7050  ...  0.8430  0.7570  0.7200  0.8540  0.7260  0.7670  0.8490
# pos       0.2950  ...  0.1310  0.2430  0.2800  0.1460  0.2740  0.1290  0.1510
# compound  0.8313  ...  0.7215  0.8102  0.9371  0.8126  0.8009  0.6764  0.6705
#
#            2998    2999    3000
# neg       0.231  0.0350  0.0300
# neu       0.769  0.8100  0.8800
# pos       0.000  0.1550  0.0910
# compound -0.961  0.8655  0.7724
#
# ...

# %%
# reverse the dataframe above
vaders = pd.DataFrame(res).T

# %%
# bring index to Id as a column
vaders =  vaders.reset_index().rename(columns={'index':'Id'})
vaders.head()
# Out:
#    Id    neg    neu    pos  compound
# 0   1  0.000  0.695  0.305    0.9441
# 1   2  0.138  0.862  0.000   -0.5664
# 2   3  0.091  0.754  0.155    0.8265
# 3   4  0.000  1.000  0.000    0.0000
# 4   5  0.000  0.552  0.448    0.9468

# %%
# merge with origianl so we have sentiment score + metadata
vaders = vaders.merge(df, how='left')
vaders.head()
# Out:
#    Id    neg    neu    pos  compound   ProductId          UserId  \
# 0   1  0.000  0.695  0.305    0.9441  B001E4KFG0  A3SGXH7AUHU8GW
# 1   2  0.138  0.862  0.000   -0.5664  B00813GRG4  A1D87F6ZCVE5NK
# 2   3  0.091  0.754  0.155    0.8265  B000LQOCH0   ABXLMWJIXXAIN
# 3   4  0.000  1.000  0.000    0.0000  B000UA0QIQ  A395BORC6FGVXV
# 4   5  0.000  0.552  0.448    0.9468  B006K2ZZ7K  A1UQRSCLF8GW1T
#
#                        ProfileName  HelpfulnessNumerator  \
# 0                       delmartian                     1
# 1                           dll pa                     0
# 2  Natalia Corres "Natalia Corres"                     1
# 3                             Karl                     3
# 4    Michael D. Bigham "M. Wassir"                     0
#
#    HelpfulnessDenominator  Score        Time                Summary  \
# 0                       1      5  1303862400  Good Quality Dog Food
# 1                       0      1  1346976000      Not as Advertised
# ...

# %% [markdown]
# ## Plot VADER results

# %%
ax = sns.barplot(data=vaders, x='Score', y='compound')
ax.set_title('Compound Score by Amazon Star Reviews')
plt.show()
# Out:
# /Users/munwon/Desktop/ds/sentiment_analysis/nlp-venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/munwon/Desktop/ds/sentiment_analysis/nlp-venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/munwon/Desktop/ds/sentiment_analysis/nlp-venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
fix, axs = plt.subplots(1, 3, figsize=(15,5))
sns.barplot(data=vaders, x='Score', y='pos', ax=axs[0])
sns.barplot(data=vaders, x='Score', y='neu', ax=axs[1])
sns.barplot(data=vaders, x='Score', y='neg', ax=axs[2])
axs[0].set_title('Positive Score by Amazon Star Reviews')
axs[1].set_title('Neutral Score by Amazon Star Reviews')
axs[2].set_title('Negative Score by Amazon Star Reviews')
plt.tight_layout()
plt.show()
# Out:
# /Users/munwon/Desktop/ds/sentiment_analysis/nlp-venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/munwon/Desktop/ds/sentiment_analysis/nlp-venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/munwon/Desktop/ds/sentiment_analysis/nlp-venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# ## Roberta Pre-trained Model
#
# - use a model trained of a large corpus of data
# - tranformer model acccounts for the words but also the context related to words

# %%
from transformers import AutoTokenizer
from transformers import AutoModelForSequenceClassification
from scipy.special import softmax

# %%
MODEL = f"cardiffnlp/twitter-roberta-base-sentiment"
tokenizer = AutoTokenizer.from_pretrained(MODEL)
model = AutoModelForSequenceClassification.from_pretrained(MODEL)

# %%
# VADER results on example
print(example)
sia.polarity_scores(example)
# Out:
# This oatmeal is not good. Its mushy, soft, I don't like it. Quaker Oats is the way to go.
# {'neg': 0.22, 'neu': 0.78, 'pos': 0.0, 'compound': -0.5448}

# %%
# run on the ROBERTA model
encoded_text = tokenizer(example, return_tensors="pt")
output = model(**encoded_text)
scores = output[0][0].detach().numpy()
scores = softmax(scores)

scores_dict = {
    'roberta_negative': scores[0],
    'roberta_neutral': scores[1],
    'roberta_positive': scores[2]
}
print(scores_dict)

# much better results than VADER
# Out:
# {'roberta_negative': 0.97635514, 'roberta_neutral': 0.020687481, 'roberta_positive': 0.0029573722}

# %%
# function for ROBERTA
def polarity_scores_roberta(example):
    encoded_text = tokenizer(example, return_tensors="pt")
    output = model(**encoded_text)
    scores = output[0][0].detach().numpy()
    scores = softmax(scores)

    scores_dict = {
        'roberta_negative': scores[0],
        'roberta_neutral': scores[1],
        'roberta_positive': scores[2]
}
    return scores_dict

# %%
res = {}

for i, row in tqdm(subset_df.iterrows(), total=len(subset_df)):
    try:

        text = row['Text']
        myid = row['Id']

        # VADER
        vader_result = sia.polarity_scores(text)
        vader_result_rename = {}
        for key, value in vader_result.items():
            vader_result_rename[f"vader_{key}"] = value

        # ROBERTA
        roberta_result = polarity_scores_roberta(text)

        combined = {**vader_result, **roberta_result}

        res[myid] = combined

    except RuntimeError:
        print(f'Broke for id {myid}')
# Out:
#   0%|          | 0/3000 [00:00<?, ?it/s]
# Broke for id 83
# Broke for id 187
# Broke for id 529
# Broke for id 540
# Broke for id 746
# Broke for id 863
# Broke for id 1053
# Broke for id 1070
# Broke for id 1156
# Broke for id 1321
# Broke for id 1375
# Broke for id 1498
# Broke for id 1575
# Broke for id 1796
# Broke for id 1826
# Broke for id 2169
# Broke for id 2248
# Broke for id 2476
# Broke for id 2492
# Broke for id 2584
# Broke for id 2610
# Broke for id 2897
# Broke for id 2898
# Broke for id 2902
# Broke for id 2928
# Broke for id 2942
# Broke for id 2944
# Broke for id 2947
# Broke for id 2948

# %%
results_subset_df = pd.DataFrame(res).T
results_subset_df = results_subset_df.reset_index().rename(columns={'index':'Id'})
results_subset_df = results_subset_df.merge(subset_df, how='left')

# %%
results_subset_df.head()
# Out:
#    Id    neg    neu    pos  compound  roberta_negative  roberta_neutral  \
# 0   1  0.000  0.695  0.305    0.9441          0.009624         0.049980
# 1   2  0.138  0.862  0.000   -0.5664          0.508986         0.452414
# 2   3  0.091  0.754  0.155    0.8265          0.003229         0.098067
# 3   4  0.000  1.000  0.000    0.0000          0.002295         0.090219
# 4   5  0.000  0.552  0.448    0.9468          0.001635         0.010302
#
#    roberta_positive   ProductId          UserId  \
# 0          0.940396  B001E4KFG0  A3SGXH7AUHU8GW
# 1          0.038600  B00813GRG4  A1D87F6ZCVE5NK
# 2          0.898704  B000LQOCH0   ABXLMWJIXXAIN
# 3          0.907486  B000UA0QIQ  A395BORC6FGVXV
# 4          0.988063  B006K2ZZ7K  A1UQRSCLF8GW1T
#
#                        ProfileName  HelpfulnessNumerator  \
# 0                       delmartian                     1
# 1                           dll pa                     0
# 2  Natalia Corres "Natalia Corres"                     1
# ...

# %% [markdown]
# ## Compare Scores between models

# %%
results_subset_df.columns
# Out:
# Index(['Id', 'neg', 'neu', 'pos', 'compound', 'roberta_negative',
#        'roberta_neutral', 'roberta_positive', 'ProductId', 'UserId',
#        'ProfileName', 'HelpfulnessNumerator', 'HelpfulnessDenominator',
#        'Score', 'Time', 'Summary', 'Text'],
#       dtype='object')

# %%
sns.pairplot(data=results_subset_df,
             vars= ['neg', 'neu', 'pos', 'compound',
                  'roberta_negative','roberta_neutral', 'roberta_positive'],
                  hue = 'Score',
                  palette='tab10')
plt.show()
# Out:
# /Users/munwon/Desktop/ds/sentiment_analysis/nlp-venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/munwon/Desktop/ds/sentiment_analysis/nlp-venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/munwon/Desktop/ds/sentiment_analysis/nlp-venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# ## Review Examples

# %%
results_subset_df.query('Score == 1').sort_values('roberta_positive', ascending=False)['Text'].values[0]
# Out:
# 'I got two Teas and one type of iced coffe and the rest were HOLIDAY COFFEES and APPLE CIDER!  Spicy Eggnog? Gingerbread? Bait and swtich.  The only redeeming factor - Amazon was great and issued me a refund.'

# %%
results_subset_df.query('Score == 1').sort_values('pos', ascending=False)['Text'].values[0]
# Out:
# 'So we cancelled the order.  It was cancelled without any problem.  That is a positive note...'

# %%
# negative sentiment 5-star review
results_subset_df.query('Score == 5').sort_values('roberta_negative', ascending=False)['Text'].values[0]
# Out:
# 'this was sooooo deliscious but too bad i ate em too fast and gained 2 pds! my fault'

# %% [markdown]
# ## Easy hugging face transformers pipeline

# %%
from transformers import pipeline

sent_pipeline = pipeline("sentiment-analysis")
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...

# %%
sent_pipeline('This golf club is actually not that bad as the reviews say.')
# Out:
# [{'label': 'POSITIVE', 'score': 0.9969276785850525}]
